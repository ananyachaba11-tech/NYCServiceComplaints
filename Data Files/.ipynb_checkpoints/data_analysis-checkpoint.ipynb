# %%
import pandas as pd

# %%
df = pd.read_csv("complaints_with_income.csv")

# %%
df.head()
# Out:
#    unique_key            created_date             closed_date  \
# 0    69197623  06/01/2026 02:07:09 PM  06/01/2026 02:16:05 PM
# 1    69207017  06/01/2026 02:07:00 PM  06/01/2026 02:07:00 PM
# 2    69205534  06/01/2026 02:06:58 PM  06/01/2026 02:06:58 PM
# 3    69198329  06/01/2026 02:06:52 PM  06/01/2026 02:43:43 PM
# 4    69196443  06/01/2026 02:06:51 PM  06/01/2026 04:50:30 PM
#
#                               agency_name            complaint  \
# 0         New York City Police Department      Illegal Parking
# 1  Department of Environmental Protection         Water System
# 2                 Department of Buildings         Building/Use
# 3         New York City Police Department      Illegal Parking
# 4         New York City Police Department  Noise - Residential
#
#                                     complaint_detail complaint_add_detail  \
# 0                                   Blocked Sidewalk                  NaN
# 1                              Hydrant Running (WC3)                  WC3
# 2  No Certificate Of Occupancy/Illegal/Contrary T...                  NaN
# 3                                  Blocked Bike Lane                  NaN
# 4                                   Loud Music/Party                  NaN
#
#      zip      city  status  ...          resol_upd_date    borough   latitude  \
# 0  11103   ASTORIA  Closed  ...  06/01/2026 02:16:08 PM     QUEENS  40.769581
# 1  11209  BROOKLYN  Closed  ...  06/01/2026 02:07:00 PM   BROOKLYN  40.624393
# 2  10456     BRONX    Open  ...  06/01/2026 12:00:00 AM      BRONX  40.833781
# 3  11205  BROOKLYN  Closed  ...  06/01/2026 02:43:47 PM   BROOKLYN  40.697416
# 4  10026  NEW YORK  Closed  ...  06/01/2026 04:50:33 PM  MANHATTAN  40.802451
#
#    longitude  median_hh_income_x median_hh_income_y median_hh_income    pop  \
# 0 -73.915593               93324              93324          93324.0  35163
# 1 -74.038340               93854              93854          93854.0  71004
# 2 -73.913806               34954              34954          34954.0  87533
# 3 -73.956717               93887              93887          93887.0  51676
# 4 -73.946622               81244              81244          81244.0  37123
#
#        income_category               complaint_group
# 0  Lower-middle income          parking and vehicles
# 1  Lower-middle income  drainage, water and plumbing
# 2        Lowest income                  building/use
# 3  Lower-middle income          parking and vehicles
# 4  Lower-middle income                         noise
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (3821055, 21)

# %%
#Checking income categories 
df['income_category'].value_counts(normalize=True)*100
# Out:
# income_category
# Lowest income          46.349634
# Lower-middle income    25.633470
# Upper-middle income    14.790994
# Highest income         13.225902
# Name: proportion, dtype: float64

# %% [markdown]
# # Do richer neighbourhoods complaint more?

# %%
# Creating zip level dataset_one

df_zip = df.groupby("zip").agg(
    complaint_count=("unique_key", "count"),_
    pop=("pop", "first"),
    median_hh_income=("median_hh_income", "first"),
    income_category=("income_category", "first")
).reset_index()

# %%
df_zip
# Out:
#        zip  complaint_count    pop  median_hh_income      income_category
# 0    10001            20837  30511          129852.0       Highest income
# 1    10002            31094  76873           48386.0        Lowest income
# 2    10003            27330  53560          154262.0       Highest income
# 3    10004             5991   3711          250000.0       Highest income
# 4    10005             3596   9439          190233.0       Highest income
# ..     ...              ...    ...               ...                  ...
# 225  12203                1  30771           83147.0  Lower-middle income
# 226  12524                2  15026           99034.0  Upper-middle income
# 227  14068                2   8636           98750.0  Upper-middle income
# 228  14223                1  22611           84161.0  Lower-middle income
# 229  14845                1  20327           76832.0  Lower-middle income
#
# [230 rows x 5 columns]

# %%
# creating complaints per 100K column 

df_zip["complaints_per_100k"] = (
    df_zip["complaint_count"] / df_zip["pop"] * 100000
)

# %%
df_zip
# Out:
#        zip  complaint_count    pop  median_hh_income      income_category  \
# 0    10001            20837  30511          129852.0       Highest income
# 1    10002            31094  76873           48386.0        Lowest income
# 2    10003            27330  53560          154262.0       Highest income
# 3    10004             5991   3711          250000.0       Highest income
# 4    10005             3596   9439          190233.0       Highest income
# ..     ...              ...    ...               ...                  ...
# 225  12203                1  30771           83147.0  Lower-middle income
# 226  12524                2  15026           99034.0  Upper-middle income
# 227  14068                2   8636           98750.0  Upper-middle income
# 228  14223                1  22611           84161.0  Lower-middle income
# 229  14845                1  20327           76832.0  Lower-middle income
#
#      complaints_per_100k
# 0           68293.402379
# 1           40448.531994
# 2           51026.885736
# 3          161438.965238
# 4           38097.256065
# ..                   ...
# 225             3.249813
# 226            13.310262
# 227            23.158870
# 228             4.422626
# 229             4.919565
#
# [230 rows x 6 columns]

# %%
df_zip.groupby("income_category")["zip"].count() 
# So the comparison is fair at the ZIP level, we have equal zips across income levels
# Out:
# income_category
# Highest income         58
# Lower-middle income    57
# Lowest income          58
# Upper-middle income    57
# Name: zip, dtype: int64

# %%
df_zip.groupby("income_category")["complaints_per_100k"].mean()
# Out:
# income_category
# Highest income         31347.734152
# Lower-middle income    37999.485618
# Lowest income          48449.926995
# Upper-middle income    25147.532631
# Name: complaints_per_100k, dtype: float64

# %%
df_zip.groupby("income_category")["complaints_per_100k"].median()
# Out:
# income_category
# Highest income         22894.496958
# Lower-middle income    40266.621572
# Lowest income          44194.880451
# Upper-middle income    28151.049513
# Name: complaints_per_100k, dtype: float64

# %% [markdown]
# **Richer ZIP codes do not appear to complain more after adjusting for population. In this analysis, lower-income ZIPs have higher 311 complaint rates per 100,000 residents. This does not prove that lower-income residents complain more; it could also reflect more 311-reportable problems in those ZIPs.**

# %% [markdown]
# # How do complaint types differ between lower-income and higher-income ZIPs?

# %%
complaint_by_income = (
    df
    .groupby("income_category")["complaint_group"]
    .value_counts(normalize=True)
    .mul(100)
    .reset_index(name="percent")
)

complaint_by_income.head(20)
# Out:
#    income_category                 complaint_group    percent
# 0   Highest income                           noise  18.224307
# 1   Highest income            parking and vehicles  17.662144
# 2   Highest income    drainage, water and plumbing   8.656645
# 3   Highest income                      encampment   5.459773
# 4   Highest income  dirty or unsanitary conditions   5.388142
# 5   Highest income      homeless person assistance   3.241196
# 6   Highest income              vendor enforcement   3.154922
# 7   Highest income                street condition   3.012848
# 8   Highest income              noise - helicopter   2.516379
# 9   Highest income      for hire vehicle complaint   1.932449
# 10  Highest income        traffic signal condition   1.624556
# 11  Highest income                     snow or ice   1.266995
# 12  Highest income   general construction/plumbing   1.186460
# 13  Highest income                   drug activity   1.145698
# 14  Highest income         maintenance or facility   1.049134
# 15  Highest income                         traffic   0.987991
# 16  Highest income     non-emergency police matter   0.952769
# 17  Highest income              sidewalk condition   0.879555
# 18  Highest income                          rodent   0.842355
# 19  Highest income              consumer complaint   0.833253

# %%
top10 = (
    complaint_by_income
    .groupby("income_category")
    .head(10)
)

top10
# Out:
#          income_category                 complaint_group    percent
# 0         Highest income                           noise  18.224307
# 1         Highest income            parking and vehicles  17.662144
# 2         Highest income    drainage, water and plumbing   8.656645
# 3         Highest income                      encampment   5.459773
# 4         Highest income  dirty or unsanitary conditions   5.388142
# 5         Highest income      homeless person assistance   3.241196
# 6         Highest income              vendor enforcement   3.154922
# 7         Highest income                street condition   3.012848
# 8         Highest income              noise - helicopter   2.516379
# 9         Highest income      for hire vehicle complaint   1.932449
# 159  Lower-middle income            parking and vehicles  30.127140
# 160  Lower-middle income                           noise  17.019834
# 161  Lower-middle income    drainage, water and plumbing  14.528382
# 162  Lower-middle income  dirty or unsanitary conditions   7.038916
# 163  Lower-middle income                street condition   3.126286
# 164  Lower-middle income                     snow or ice   2.026200
# 165  Lower-middle income                   paint/plaster   1.429754
# 166  Lower-middle income        traffic signal condition   1.393714
# 167  Lower-middle income                    damaged tree   1.121220
# 168  Lower-middle income                     door/window   1.069763
# 315        Lowest income                           noise  24.243088
# 316        Lowest income            parking and vehicles  19.831794
# 317        Lowest income    drainage, water and plumbing  19.670703
# 318        Lowest income  dirty or unsanitary conditions   7.546618
# 319        Lowest income                   paint/plaster   2.384524
# 320        Lowest income                     door/window   1.815256
# 321        Lowest income                street condition   1.759808
# 322        Lowest income                         general   1.306009
# 323        Lowest income                        electric   1.153782
# 324        Lowest income        traffic signal condition   1.115330
# 476  Upper-middle income            parking and vehicles  27.518171
# 477  Upper-middle income                           noise  14.771079
# 478  Upper-middle income    drainage, water and plumbing  10.431338
# 479  Upper-middle income  dirty or unsanitary conditions   6.887284
# 480  Upper-middle income                street condition   4.926465
# 481  Upper-middle income                     snow or ice   3.334737
# 482  Upper-middle income                    damaged tree   1.793259
# 483  Upper-middle income        traffic signal condition   1.720538
# 484  Upper-middle income          street light condition   1.377457
# 485  Upper-middle income   general construction/plumbing   1.309867

# %% [markdown]
# **noise, drainage water and plumbing, and parking and vehicles, dirty/unsanitary conditions are the top four categories across all income groups.**
#
# * **Noise complaints** make up **24.2%** of complaints in the **lowest-income ZIPs**, compared with **18.2%** in the **highest-income ZIPs** and **14.5–16.7%** in the middle-income groups.
#
# * **Drainage, water and plumbing** complaints account for **20.0%** of complaints in the **lowest-income ZIPs**, more than double the share in the **highest-income ZIPs** (**9.0%**) and substantially higher than in the middle-income groups (**10.7–15.0%**).
#
# * **Parking and vehicle** complaints show the opposite pattern. They are the largest complaint category in the middle-income groups (**30.1%** in lower-middle and **27.5%** in upper-middle ZIPs), compared with **19.8%** in the lowest-income and **17.6%** in the highest-income ZIPs.
#
# * **Dirty or unsanitary conditions** are relatively stable across income groups, accounting for **5.3–7.5%** of complaints regardless of income.
#
# * Several complaint types are much more prominent in **higher-income ZIPs**, including **encampment (5.3%)**, **homeless person assistance (3.2%)**, **vendor enforcement (3.1%)**, and **noise – helicopter (2.5%)**. None of these appear among the top complaints in the lower-income groups.

# %% [markdown]
# # How do response times by the city differ across rich and poorer neighbourhoods?

# %%
df["created_date"] = pd.to_datetime(
    df["created_date"],
    format="%m/%d/%Y %I:%M:%S %p"
)

df["closed_date"] = pd.to_datetime(
    df["closed_date"],
    format="%m/%d/%Y %I:%M:%S %p"
)

# %%
df['created_date'].dtype
df['closed_date'].dtype
# now they are in the right format
# Out:
# dtype('<M8[us]')

# %%
#creating another column called response_days
df["response_days"] = ((df["closed_date"] - df["created_date"]).dt.total_seconds())/ 86400

# %% [markdown]
# ### Noise

# %%
# checking that all noise is handled by same agency or not
df_noise = df[df['complaint_group'] == 'noise']

# %%
df_noise["agency_name"].value_counts(normalize=True).cumsum()
# so it should be reasonable to check for response time to noise complaint within the broader category.
# Out:
# agency_name
# New York City Police Department           0.924712
# Department of Environmental Protection    1.000000
# Name: proportion, dtype: float64

# %%
df[df["complaint_group"] == "noise"] \
    .groupby("agency_name")["response_days"] \
    .median()
# Out:
# agency_name
# Department of Environmental Protection    2.820486
# New York City Police Department           0.041690
# Name: response_days, dtype: float64

# %%
(
    df[df["complaint_group"] == "noise"]
    .groupby("income_category")["agency_name"]
    .value_counts(normalize=True)
    .mul(100)
)
# Out:
# income_category      agency_name
# Highest income       New York City Police Department           78.208469
#                      Department of Environmental Protection    21.791531
# Lower-middle income  New York City Police Department           93.196924
#                      Department of Environmental Protection     6.803076
# Lowest income        New York City Police Department           96.060146
#                      Department of Environmental Protection     3.939854
# Upper-middle income  New York City Police Department           88.299274
#                      Department of Environmental Protection    11.700726
# Name: proportion, dtype: float64

# %%
#separating noise from environmental protection dept 

df_noise_nypd = df[
    (df["complaint_group"] == "noise") &
    (df["agency_name"] == "New York City Police Department")
].copy()

# %%
df_noise_nypd.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         0.671667
# Lower-middle income    1.119167
# Lowest income          1.056389
# Upper-middle income    0.939167
# Name: response_days, dtype: float64

# %% [markdown]
# **Among NYPD-handled noise complaints, median response times are slightly faster in the highest-income ZIP codes (0.68 hours) than in the other income groups (0.97–1.15 hours). However, the differences are relatively small—measured in minutes rather than days—and could reflect factors such as patrol locations, call volume, or geographic differences rather than differences in service quality. This analysis alone does not provide evidence of systematic bias in response times.**

# %% [markdown]
# ### parking and vehicles

# %%
# checking that all noise is handled by same agency or not
df_parking = df[df['complaint_group'] == 'parking and vehicles']

# %%
df_parking["agency_name"].value_counts(normalize=True).cumsum()
# so it should be reasonable to check for response time to noise complaint within the broader category.
# Out:
# agency_name
# New York City Police Department    0.959284
# Department of Sanitation           1.000000
# Name: proportion, dtype: float64

# %%
df[df["complaint_group"] == "parking and vehicles"] \
    .groupby("agency_name")["response_days"] \
    .median()*24
# Out:
# agency_name
# Department of Sanitation           21.608333
# New York City Police Department     1.521667
# Name: response_days, dtype: float64

# %%
(
    df[df["complaint_group"] == "parking and vehicles"]
    .groupby("income_category")["agency_name"]
    .value_counts(normalize=True)
    .mul(100)
)
# Out:
# income_category      agency_name
# Highest income       New York City Police Department    98.700411
#                      Department of Sanitation            1.299589
# Lower-middle income  New York City Police Department    95.778519
#                      Department of Sanitation            4.221481
# Lowest income        New York City Police Department    95.373117
#                      Department of Sanitation            4.626883
# Upper-middle income  New York City Police Department    95.875904
#                      Department of Sanitation            4.124096
# Name: proportion, dtype: float64

# %%
#separating noise from environmental protection dept 

df_parking_nypd = df[
    (df["complaint_group"] == "parking and vehicles") &
    (df["agency_name"] == "New York City Police Department")
].copy()

df_parking_dos = df[
    (df["complaint_group"] == "parking and vehicles") &
    (df["agency_name"] == "Department of Sanitation")
].copy()

# %%
df_parking_nypd.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         1.012778
# Lower-middle income    1.658611
# Lowest income          1.696111
# Upper-middle income    1.356111
# Name: response_days, dtype: float64

# %%
df_parking_dos.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         19.350000
# Lower-middle income    21.316667
# Lowest income          21.666667
# Upper-middle income    22.558333
# Name: response_days, dtype: float64

# %% [markdown]
# **Again, the highest-income ZIPs receive slightly faster responses, but we're talking about a difference of roughly 40 minutes to 1 hour.**

# %% [markdown]
# ### drainage, water, and plumbing

# %%
# checking that all noise is handled by same agency or not
df_water = df[df['complaint_group'] == 'drainage, water and plumbing']

# %%
df_water["agency_name"].value_counts(normalize=True).cumsum()
# so it should be reasonable to check for response time to noise complaint within the broader category.
# Out:
# agency_name
# Department of Housing Preservation and Development    0.804008
# Department of Environmental Protection                1.000000
# Name: proportion, dtype: float64

# %%
#separating agencies

df_water_dhpd = df[
    (df["complaint_group"] == "drainage, water and plumbing") &
    (df["agency_name"] == "Department of Housing Preservation and Development")
].copy()

df_water_dep = df[
    (df["complaint_group"] == "drainage, water and plumbing") &
    (df["agency_name"] == "Department of Environmental Protection")
].copy()

# %%
df_water_dhpd.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         53.135417
# Lower-middle income    51.147639
# Lowest income          49.169167
# Upper-middle income    55.318750
# Name: response_days, dtype: float64

# %%
df_water_dep.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         3.016667
# Lower-middle income    4.783333
# Lowest income          3.366667
# Upper-middle income    6.791667
# Name: response_days, dtype: float64

# %% [markdown]
# ***No clear pattern***

# %% [markdown]
# ### dirty or unsanitary conditions

# %%
# checking that all noise is handled by same agency or not
df_dirty = df[df['complaint_group'] == 'dirty or unsanitary conditions']

# %%
df_dirty["agency_name"].value_counts(normalize=True)
# so it should be reasonable to check for response time to noise complaint within the broader category.
# Out:
# agency_name
# Department of Sanitation                              0.527644
# Department of Housing Preservation and Development    0.472356
# Name: proportion, dtype: float64

# %%
#separating agencies

df_dirty_ds = df[
    (df["complaint_group"] == "dirty or unsanitary conditions") &
    (df["agency_name"] == "Department of Sanitation")
].copy()

df_dirty_dhpd = df[
    (df["complaint_group"] == "dirty or unsanitary conditions") &
    (df["agency_name"] == "Department of Housing Preservation and Development")
].copy()

# %%
df_dirty_ds.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         29.012500
# Lower-middle income    40.543750
# Lowest income          42.979167
# Upper-middle income    46.613056
# Name: response_days, dtype: float64

# %%
df_dirty_dhpd.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         414.833889
# Lower-middle income    238.588889
# Lowest income          260.218333
# Upper-middle income    284.886111
# Name: response_days, dtype: float64

# %% [markdown]
# ***Response times are strongly influenced by the type of complaint and the agency responsible for resolving it. After accounting for agency, some complaint types are resolved slightly faster in higher-income ZIPs, while others show little difference or even the opposite pattern.***

# %% [markdown]
# # NYPD

# %%
df_nypd = df[
    df["agency_name"] == "New York City Police Department"
].copy()

df_nypd["complaint_group"].value_counts(normalize=True).mul(100).head(15)
# Out:
# complaint_group
# parking and vehicles           49.948668
# noise                          41.693930
# encampment                      1.813435
# non-emergency police matter     1.467460
# drug activity                   1.341539
# animal-abuse                    0.654029
# illegal fireworks               0.651107
# traffic                         0.633052
# noise - park                    0.556155
# panhandling                     0.488783
# drinking                        0.267092
# noise - house of worship        0.207609
# urinating in public             0.092206
# bike/roller/skate chronic       0.059893
# bike/roller/skate               0.052180
# Name: proportion, dtype: float64

# %% [markdown]
# ### encampment

# %%
# checking that all encampment complaints are handled by same agency or not
df_encamp = df[df['complaint_group'] == 'encampment']

# %%
df_encamp["agency_name"].value_counts(normalize=True)
# Out:
# agency_name
# New York City Police Department    0.684857
# Department of Homeless Services    0.315143
# Name: proportion, dtype: float64

# %%
#separating agencies

df_encamp_nypd = df[
    (df["complaint_group"] == "encampment") &
    (df["agency_name"] == "New York City Police Department")
].copy()

df_encamp_dhs = df[
    (df["complaint_group"] == "encampment") &
    (df["agency_name"] == "Department of Homeless Services")
].copy()

# %%
df_encamp_nypd.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income         0.884167
# Lower-middle income    1.808333
# Lowest income          1.491944
# Upper-middle income    1.141389
# Name: response_days, dtype: float64

# %%
df_encamp_dhs.groupby('income_category')['response_days'].median()*24
# Out:
# income_category
# Highest income          34.738889
# Lower-middle income     53.288750
# Lowest income          126.746528
# Upper-middle income     45.782500
# Name: response_days, dtype: float64

# %%
df_encamp_dhs.groupby("income_category").size()
# Out:
# income_category
# Highest income         9582
# Lower-middle income    1007
# Lowest income          2086
# Upper-middle income    1606
# dtype: int64

# %% [markdown]
# - ***Highest income zips get fastest responses for encampment***
# - ***Encampment complaints are much larger in highest income categories -> complaints do differ for some reason in higher income neighbourhoods***

# %%
agency_counts = (
    df
    .groupby(["complaint_group", "agency_name"])
    .size()
    .reset_index(name="n")
    .sort_values("n", ascending=False)
)

agency_counts.head(20)
# Out:
#                     complaint_group  \
# 117            parking and vehicles
# 103                           noise
# 48     drainage, water and plumbing
# 44   dirty or unsanitary conditions
# 43   dirty or unsanitary conditions
# 47     drainage, water and plumbing
# 146                street condition
# 114                   paint/plaster
# 139                     snow or ice
# 102                           noise
# 162        traffic signal condition
# 46                      door/window
# 69                          general
# 70    general construction/plumbing
# 116            parking and vehicles
# 148          street light condition
# 55                         electric
# 35                     damaged tree
# 77       homeless person assistance
# 61                       encampment
#
#                                            agency_name       n
# 117                    New York City Police Department  854818
# 103                    New York City Police Department  713547
# 48   Department of Housing Preservation and Develop...  477083
# 44                            Department of Sanitation  141806
# 43   Department of Housing Preservation and Develop...  126947
# 47              Department of Environmental Protection  116298
# 146                       Department of Transportation  104540
# 114  Department of Housing Preservation and Develop...   64132
# 139                           Department of Sanitation   63691
# 102             Department of Environmental Protection   58095
# 162                       Department of Transportation   51338
# 46   Department of Housing Preservation and Develop...   49885
# 69   Department of Housing Preservation and Develop...   37482
# 70                             Department of Buildings   37100
# 116                           Department of Sanitation   36282
# 148                       Department of Transportation   33538
# 55   Department of Housing Preservation and Develop...   33499
# 35                  Department of Parks and Recreation   33370
# 77                     Department of Homeless Services   32835
# 61                     New York City Police Department   31035

# %%
response_summary = (
    df
    .groupby(["complaint_group", "agency_name", "income_category"])
    .agg(
        n=("unique_key", "count"),
        median_hours=("response_days", lambda x: x.median() * 24),
        mean_hours=("response_days", lambda x: x.mean() * 24)
    )
    .reset_index()
)

response_summary.head(20)
# Out:
#                 complaint_group                              agency_name  \
# 0                abandoned bike                 Department of Sanitation
# 1                abandoned bike                 Department of Sanitation
# 2                abandoned bike                 Department of Sanitation
# 3                abandoned bike                 Department of Sanitation
# 4           ahv inspection unit                  Department of Buildings
# 5           ahv inspection unit                  Department of Buildings
# 6           ahv inspection unit                  Department of Buildings
# 7                   air quality   Department of Environmental Protection
# 8                   air quality   Department of Environmental Protection
# 9                   air quality   Department of Environmental Protection
# 10                  air quality   Department of Environmental Protection
# 11  animal facility - no permit  Department of Health and Mental Hygiene
# 12  animal facility - no permit  Department of Health and Mental Hygiene
# 13  animal facility - no permit  Department of Health and Mental Hygiene
# 14  animal facility - no permit  Department of Health and Mental Hygiene
# 15             animal in a park       Department of Parks and Recreation
# 16             animal in a park       Department of Parks and Recreation
# 17             animal in a park       Department of Parks and Recreation
# 18             animal in a park       Department of Parks and Recreation
# 19                 animal-abuse          New York City Police Department
#
#         income_category     n  median_hours  mean_hours
# 0        Highest income   588     67.573333   91.655496
# 1   Lower-middle income   486     68.437778  100.069924
# 2         Lowest income   628     64.592778   99.908815
# 3   Upper-middle income   412     97.428333  125.332303
# 4        Highest income    16    243.120556  401.961840
# 5         Lowest income     7    104.207500  159.029087
# 6   Upper-middle income     7    210.278611  333.961071
# 7        Highest income  3051     45.083333   70.199273
# 8   Lower-middle income  1623     49.416667   72.125303
# 9         Lowest income  2038     56.800000   83.640987
# 10  Upper-middle income  2678     41.933333   61.303167
# 11       Highest income    25      0.000000  127.444444
# 12  Lower-middle income    25      0.000000    8.258077
# 13        Lowest income    28      0.000000   57.607639
# 14  Upper-middle income    14      0.000000   39.434889
# 15       Highest income  1633      1.520278   47.915460
# 16  Lower-middle income  1069      1.357917   66.713610
# 17        Lowest income  1215      1.398333   56.075950
# 18  Upper-middle income  1531      1.411806   58.911954
# 19       Highest income  1275      0.970278    1.663469
